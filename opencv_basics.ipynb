# %%
from cv2 import cv2
from matplotlib import pyplot as plt

# %%
img=cv2.imread("Resources/Data/brain1.jpeg")

# %%
plt.imshow(img)

# %%
img3=cv2.imread("Resources/Data/o.jpg",0)
img4=cv2.imread("Resources/Data/p.jpg",0)

# %%
plt.imshow(img3)

# %%
plt.imshow(img4)

# %%
result=img4+img3
plt.imshow(result)

# %%
result=img4-img3
plt.imshow(result)

# %%
result=img4*img3
plt.imshow(result)

# %%
result=img4/img3
plt.imshow(result)
# Out:
# C:\Users\renusri\AppData\Local\Temp\ipykernel_14816\2069585978.py:1: RuntimeWarning: divide by zero encountered in true_divide
#   result=img4/img3
